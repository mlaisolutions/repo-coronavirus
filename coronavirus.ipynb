# %%
import geopandas as gpd
import pandas as pd

confirmed_filepath = "./input/time_series_covid_19_confirmed.csv"

# Your code here: Load the data
confirmed_df = gpd.read_file(confirmed_filepath)
#confirmed_df = confirmed_df['Province/State','Country/Region','Lat','Long','02/20/20','geometry']]

# Convert the DataFrame to a GeoDataFrame
confirmed_df['Lat'] = confirmed_df['Lat'].astype(float)
confirmed_df['Long'] = confirmed_df['Long'].astype(float)
confirmed = gpd.GeoDataFrame(confirmed_df, geometry=gpd.points_from_xy(confirmed_df.Long, confirmed_df.Lat))
# Set the coordinate reference system (CRS) to EPSG 4326
confirmed.crs = {'init': 'epsg:4326'}
# View the first five rows of the GeoDataFrame
confirmed.head()
# Out:
#   Province/State  Country/Region       Lat      Long 1/22/20 1/23/20 1/24/20  \
# 0          Anhui  Mainland China  31.82571  117.2264       1       9      15
# 1        Beijing  Mainland China  40.18238  116.4142      14      22      36
# 2      Chongqing  Mainland China  30.05718  107.8740       6       9      27
# 3         Fujian  Mainland China  26.07783  117.9895       1       5      10
# 4          Gansu  Mainland China  36.06110  103.8343       0       2       2
#
#   1/25/20 1/26/20 1/27/20  ... 2/12/20 2/13/20 2/14/20 2/15/20 2/16/20  \
# 0      39      60      70  ...     889     910     934     950     962
# 1      41      68      80  ...     352     366     372     375     380
# 2      57      75     110  ...     518     529     537     544     551
# 3      18      35      59  ...     272     279     281     285     287
# 4       4       7      14  ...      87      90      90      90      90
#
#   2/17/20 2/18/20 2/19/20 2/20/20                    geometry
# 0     973     982     986     987  POINT (117.22640 31.82571)
# 1     381     387     393     395  POINT (116.41420 40.18238)
# 2     553     555     560     567  POINT (107.87400 30.05718)
# 3     290     292     293     293  POINT (117.98950 26.07783)
# 4      91      91      91      91  POINT (103.83430 36.06110)
#
# [5 rows x 35 columns]

# %%
deaths_filepath = "./input/time_series_covid_19_deaths.csv"
deaths_df = gpd.read_file(deaths_filepath)
deaths_df['Lat'] = deaths_df['Lat'].astype(float)
deaths_df['Long'] = deaths_df['Long'].astype(float)
deaths = gpd.GeoDataFrame(deaths_df, geometry=gpd.points_from_xy(deaths_df.Long, deaths_df.Lat))
# Set the coordinate reference system (CRS) to EPSG 4326
deaths.crs = {'init': 'epsg:4326'}
# View the first five rows of the GeoDataFrame
deaths.head()
# Out:
#   Province/State  Country/Region       Lat      Long 1/22/20 1/23/20 1/24/20  \
# 0          Anhui  Mainland China  31.82571  117.2264       0       0       0
# 1        Beijing  Mainland China  40.18238  116.4142       0       0       0
# 2      Chongqing  Mainland China  30.05718  107.8740       0       0       0
# 3         Fujian  Mainland China  26.07783  117.9895       0       0       0
# 4          Gansu  Mainland China  36.06110  103.8343       0       0       0
#
#   1/25/20 1/26/20 1/27/20  ... 2/12/20 2/13/20 2/14/20 2/15/20 2/16/20  \
# 0       0       0       0  ...       4       5       6       6       6
# 1       0       0       1  ...       3       3       3       4       4
# 2       0       0       0  ...       3       4       5       5       5
# 3       0       0       0  ...       0       0       0       0       0
# 4       0       0       0  ...       2       2       2       2       2
#
#   2/17/20 2/18/20 2/19/20 2/20/20                    geometry
# 0       6       6       6       6  POINT (117.22640 31.82571)
# 1       4       4       4       4  POINT (116.41420 40.18238)
# 2       5       5       5       6  POINT (107.87400 30.05718)
# 3       0       0       0       1  POINT (117.98950 26.07783)
# 4       2       2       2       2  POINT (103.83430 36.06110)
#
# [5 rows x 35 columns]

# %%
recovered_filepath = "./input/time_series_covid_19_recovered.csv"
recovered_df = gpd.read_file(recovered_filepath)
recovered_df['Lat'] = recovered_df['Lat'].astype(float)
recovered_df['Long'] = recovered_df['Long'].astype(float)
recovered = gpd.GeoDataFrame(recovered_df, geometry=gpd.points_from_xy(recovered_df.Long, recovered_df.Lat))
# Set the coordinate reference system (CRS) to EPSG 4326
recovered.crs = {'init': 'epsg:4326'}
# View the first five rows of the GeoDataFrame
recovered.head()
# Out:
#   Province/State  Country/Region       Lat      Long 1/22/20 1/23/20 1/24/20  \
# 0          Anhui  Mainland China  31.82571  117.2264       0       0       0
# 1        Beijing  Mainland China  40.18238  116.4142       0       0       1
# 2      Chongqing  Mainland China  30.05718  107.8740       0       0       0
# 3         Fujian  Mainland China  26.07783  117.9895       0       0       0
# 4          Gansu  Mainland China  36.06110  103.8343       0       0       0
#
#   1/25/20 1/26/20 1/27/20  ... 2/12/20 2/13/20 2/14/20 2/15/20 2/16/20  \
# 0       0       0       0  ...     127     157     193     221     255
# 1       2       2       2  ...      56      69      80      98     108
# 2       0       0       0  ...     102     128     152     184     207
# 3       0       0       0  ...      53      57      63      71      82
# 4       0       0       0  ...      31      39      39      49      54
#
#   2/17/20 2/18/20 2/19/20 2/20/20                    geometry
# 0     280     361     413     474  POINT (117.22640 31.82571)
# 1     114     122     145     153  POINT (116.41420 40.18238)
# 2     225     254     274     299  POINT (107.87400 30.05718)
# 3      90      93     112     126  POINT (117.98950 26.07783)
# 4      58      62      65      71  POINT (103.83430 36.06110)
#
# [5 rows x 35 columns]

# %%
world_filepath = gpd.datasets.get_path('naturalearth_lowres')
world = gpd.read_file(world_filepath)
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
ax = world.plot(figsize=(10,10), color='none', edgecolor='gainsboro', zorder=3)
confirmed.plot(color='red', ax=ax)
deaths.plot(color='black', markersize=2, ax=ax)
recovered.plot(color='green', markersize=1, ax=ax)
